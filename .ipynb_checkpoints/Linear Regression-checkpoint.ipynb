# %%
import numpy as np
import pandas as pd
from scipy.stats import pearsonr
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
df.tail(10)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 21603  7852140040  20140825T000000   507250.0         3       2.50
# 21604  9834201367  20150126T000000   429000.0         3       2.00
# 21605  3448900210  20141014T000000   610685.0         4       2.50
# 21606  7936000429  20150326T000000  1007500.0         4       3.50
# 21607  2997800021  20150219T000000   475000.0         3       2.50
# 21608   263000018  20140521T000000   360000.0         3       2.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
# 21610  1523300141  20140623T000000   402101.0         2       0.75
# 21611   291310100  20150116T000000   400000.0         3       2.50
# 21612  1523300157  20141015T000000   325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view     ...      grade  \
# 21603         2270      5536     2.0           0     0     ...          8
# 21604         1490      1126     3.0           0     0     ...          8
# 21605         2520      6023     2.0           0     0     ...          9
# 21606         3510      7200     2.0           0     0     ...          9
# 21607         1310      1294     2.0           0     0     ...          8
# 21608         1530      1131     3.0           0     0     ...          8
# 21609         2310      5813     2.0           0     0     ...          8
# 21610         1020      1350     2.0           0     0     ...          7
# 21611         1600      2388     2.0           0     0     ...          8
# 21612         1020      1076     2.0           0     0     ...          7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21603        2270              0      2003             0    98065  47.5389
# 21604        1490              0      2014             0    98144  47.5699
# 21605        2520              0      2014             0    98056  47.5137
# 21606        2600            910      2009             0    98136  47.5537
# 21607        1180            130      2008             0    98116  47.5773
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 21603 -121.881           2270        5731
# 21604 -122.288           1400        1230
# 21605 -122.167           2520        6023
# 21606 -122.398           2050        6200
# 21607 -122.409           1330        1265
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [10 rows x 21 columns]

# %%
#checking the number of row and columns in the data 
df.shape
# Out:
# (21613, 21)

# %%
#Data types in the data 
#df.dtypes
df.dtypes.unique()
# Out:
# array([dtype('int64'), dtype('O'), dtype('float64')], dtype=object)

# %%
#select the data on bais of data type and getting the columns name
#df.select_dtypes(include=['O',])
#df.select_dtypes(include=['O',]).columns
df.select_dtypes(include=['O',]).columns.tolist()
# Out:
# ['date']

# %%
print(df.isnull().any().sum(), ' / ', df.shape[1])
print(df.isnull().any(axis=1).sum(), ' / ', df.shape[0])
# Out:
# 0  /  21
# 0  /  21613

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
# id               21613 non-null int64
# date             21613 non-null object
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21613 non-null float64
# waterfront       21613 non-null int64
# view             21613 non-null int64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %%
#features  = df.iloc[:,3:].columns.tolist()
features  = df.iloc[:,3:].columns.tolist()

# %%
features
# Out:
# ['bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
target = df.iloc[:,2].name

# %%
target
# Out:
# 'price'

# %%
#calculate correlation between target and all features 
#from scipy.stats import pearsonr

corr = {}

for feature in features:
    x = df[feature]
    y = df[target]
    key = feature 
    #correlation = pearsonr(x,y)
    print(correlation)
    corr[key]= correlation[0]
# Out:
# (0.3083495981456383, 0.0)
# (0.5251375054139619, 0.0)
# (0.7020350546118, 0.0)
# (0.08966086058710011, 7.972504510326147e-40)
# (0.2567938875507184, 1.6e-322)
# (0.2663694340306021, 0.0)
# (0.3972934882945043, 0.0)
# (0.036361789128997554, 8.935654062344094e-08)
# (0.6674342560202371, 0.0)
# (0.6055672983560783, 0.0)
# (0.32381602071198395, 0.0)
# (0.054011531494792715, 1.929872809374955e-15)
# (0.12643379344089295, 1.0213478858043326e-77)
# (-0.05320285429832561, 5.011050503318762e-15)
# (0.3070034799952186, 0.0)
# (0.021626241039305872, 0.0014750922063201787)
# (0.585378903579568, 0.0)
# (0.08244715251948598, 6.417559889335015e-34)

# %%
corr
# Out:
# {'bedrooms': 0.3083495981456383,
#  'bathrooms': 0.5251375054139619,
#  'sqft_living': 0.7020350546118,
#  'sqft_lot': 0.08966086058710011,
#  'floors': 0.2567938875507184,
#  'waterfront': 0.2663694340306021,
#  'view': 0.3972934882945043,
#  'condition': 0.036361789128997554,
#  'grade': 0.6674342560202371,
#  'sqft_above': 0.6055672983560783,
#  'sqft_basement': 0.32381602071198395,
#  'yr_built': 0.054011531494792715,
#  'yr_renovated': 0.12643379344089295,
#  'zipcode': -0.05320285429832561,
#  'lat': 0.3070034799952186,
#  'long': 0.021626241039305872,
#  'sqft_living15': 0.585378903579568,
#  'sqft_lot15': 0.08244715251948598}

# %%
data_correlations = pd.DataFrame(list(corr.items()), columns = ['feautes and target','corr'])

# %%
data_correlations
# Out:
#    feautes and target      corr
# 0            bedrooms  0.308350
# 1           bathrooms  0.525138
# 2         sqft_living  0.702035
# 3            sqft_lot  0.089661
# 4              floors  0.256794
# 5          waterfront  0.266369
# 6                view  0.397293
# 7           condition  0.036362
# 8               grade  0.667434
# 9          sqft_above  0.605567
# 10      sqft_basement  0.323816
# 11           yr_built  0.054012
# 12       yr_renovated  0.126434
# 13            zipcode -0.053203
# 14                lat  0.307003
# 15               long  0.021626
# 16      sqft_living15  0.585379
# 17         sqft_lot15  0.082447

# %%
#convert all the negative correlation into positive 
data_correlations['corr'] = data_correlations['corr'].abs()

# %%
data_correlations
# Out:
#    feautes and target      corr
# 0            bedrooms  0.308350
# 1           bathrooms  0.525138
# 2         sqft_living  0.702035
# 3            sqft_lot  0.089661
# 4              floors  0.256794
# 5          waterfront  0.266369
# 6                view  0.397293
# 7           condition  0.036362
# 8               grade  0.667434
# 9          sqft_above  0.605567
# 10      sqft_basement  0.323816
# 11           yr_built  0.054012
# 12       yr_renovated  0.126434
# 13            zipcode  0.053203
# 14                lat  0.307003
# 15               long  0.021626
# 16      sqft_living15  0.585379
# 17         sqft_lot15  0.082447

# %%
#get n highest correlated feature
data_correlations =data_correlations.sort_values('corr',ascending=False).iloc[:5,:].reset_index(drop=True)

# %%
data_correlations
# Out:
#   feautes and target      corr
# 0        sqft_living  0.702035
# 1              grade  0.667434
# 2         sqft_above  0.605567
# 3      sqft_living15  0.585379
# 4          bathrooms  0.525138

# %%
#get all the features name 
top_5_features = data_correlations.iloc[:,0]

# %%
top_5_features = list(top_5_features)

# %%
top_5_features
# Out:
# ['sqft_living', 'grade', 'sqft_above', 'sqft_living15', 'bathrooms']

# %%
target = list(df.iloc[:,2].values)

# %%
target
# Out:
# [221900.0,
#  538000.0,
#  180000.0,
#  604000.0,
#  510000.0,
#  1225000.0,
#  257500.0,
#  291850.0,
#  229500.0,
#  323000.0,
#  662500.0,
#  468000.0,
#  310000.0,
#  400000.0,
#  530000.0,
#  650000.0,
#  395000.0,
#  485000.0,
#  189000.0,
#  230000.0,
#  385000.0,
#  2000000.0,
#  285000.0,
#  252700.0,
#  329000.0,
#  233000.0,
#  937000.0,
#  667000.0,
#  438000.0,
#  719000.0,
#  580500.0,
#  280000.0,
#  687500.0,
#  535000.0,
#  322500.0,
#  696000.0,
#  550000.0,
#  640000.0,
#  240000.0,
#  605000.0,
#  625000.0,
#  775000.0,
#  861990.0,
#  685000.0,
#  309000.0,
#  488000.0,
#  210490.0,
#  785000.0,
#  450000.0,
#  1350000.0,
#  228000.0,
#  345000.0,
#  600000.0,
#  585000.0,
#  920000.0,
#  885000.0,
#  292500.0,
#  301000.0,
#  951000.0,
#  430000.0,
#  650000.0,
#  289000.0,
#  505000.0,
#  549000.0,
#  425000.0,
#  317625.0,
#  975000.0,
#  287000.0,
#  204000.0,
#  1325000.0,
#  1040000.0,
#  325000.0,
#  571000.0,
#  360000.0,
#  349000.0,
#  832500.0,
#  380000.0,
#  480000.0,
#  410000.0,
#  720000.0,
#  390000.0,
#  360000.0,
#  355000.0,
#  356000.0,
#  315000.0,
#  940000.0,
#  305000.0,
#  461000.0,
#  215000.0,
#  335000.0,
#  243500.0,
#  1099880.0,
#  153000.0,
#  430000.0,
#  700000.0,
#  905000.0,
#  247500.0,
#  199000.0,
#  314000.0,
#  437500.0,
#  850830.0,
#  555000.0,
#  699950.0,
#  1088000.0,
#  290000.0,
#  375000.0,
#  460000.0,
#  188500.0,
#  680000.0,
#  470000.0,
#  597750.0,
#  570000.0,
#  272500.0,
#  329950.0,
#  480000.0,
#  740500.0,
#  518500.0,
#  205425.0,
#  171800.0,
#  535000.0,
#  660000.0,
#  391500.0,
#  395000.0,
#  445000.0,
#  770000.0,
#  1450000.0,
#  445000.0,
#  260000.0,
#  822500.0,
#  430000.0,
#  212000.0,
#  660500.0,
#  784000.0,
#  453246.0,
#  675000.0,
#  199000.0,
#  220000.0,
#  452000.0,
#  382500.0,
#  519950.0,
#  665000.0,
#  527700.0,
#  205000.0,
#  420000.0,
#  500000.0,
#  921500.0,
#  890000.0,
#  430000.0,
#  258000.0,
#  511000.0,
#  532170.0,
#  560000.0,
#  282950.0,
#  2250000.0,
#  350000.0,
#  215000.0,
#  650000.0,
#  320000.0,
#  247000.0,
#  320000.0,
#  255000.0,
#  438000.0,
#  900000.0,
#  441000.0,
#  420000.0,
#  370000.0,
#  269950.0,
#  807100.0,
#  653000.0,
#  371500.0,
#  284000.0,
#  272000.0,
#  313000.0,
#  917500.0,
#  673000.0,
#  425000.0,
#  399950.0,
#  385000.0,
#  269950.0,
#  330000.0,
#  260000.0,
#  470000.0,
#  589000.0,
#  163500.0,
#  835000.0,
#  1095000.0,
#  269000.0,
#  560000.0,
#  615000.0,
#  585188.0,
#  305000.0,
#  166950.0,
#  799000.0,
#  400000.0,
#  230000.0,
#  256883.0,
#  423000.0,
#  465000.0,
#  440000.0,
#  385000.0,
#  210000.0,
#  297000.0,
#  470000.0,
#  226500.0,
#  274250.0,
#  840000.0,
#  677900.0,
#  425000.0,
#  180250.0,
#  464000.0,
#  320000.0,
#  625504.0,
#  592500.0,
#  465000.0,
#  477000.0,
#  280000.0,
#  1505000.0,
#  445838.0,
#  1072000.0,
#  467000.0,
#  686000.0,
#  279950.0,
#  527000.0,
#  325000.0,
#  328000.0,
#  390000.0,
#  479950.0,
#  264950.0,
#  235000.0,
#  516500.0,
#  655000.0,
#  500000.0,
#  315000.0,
#  213000.0,
#  475000.0,
#  1025000.0,
#  416000.0,
#  410000.0,
#  800000.0,
#  472000.0,
#  225000.0,
#  210000.0,
#  455000.0,
#  225000.0,
#  480000.0,
#  363000.0,
#  2400000.0,
#  181000.0,
#  250000.0,
#  481000.0,
#  260000.0,
#  455000.0,
#  415000.0,
#  349500.0,
#  245000.0,
#  592500.0,
#  385000.0,
#  315000.0,
#  255000.0,
#  693000.0,
#  780000.0,
#  237000.0,
#  525000.0,
#  425000.0,
#  369900.0,
#  290000.0,
#  285000.0,
#  415000.0,
#  272500.0,
#  2900000.0,
#  1365000.0,
#  436000.0,
#  210000.0,
#  236000.0,
#  331000.0,
#  365000.0,
#  450000.0,
#  770000.0,
#  455000.0,
#  405000.0,
#  304900.0,
#  170000.0,
#  2050000.0,
#  780000.0,
#  330000.0,
#  370000.0,
#  467000.0,
#  405000.0,
#  675000.0,
#  500000.0,
#  389999.0,
#  630000.0,
#  360000.0,
#  580000.0,
#  550000.0,
#  879000.0,
#  265000.0,
#  446500.0,
#  404000.0,
#  267500.0,
#  3075000.0,
#  335000.0,
#  576000.0,
#  208633.0,
#  315000.0,
#  725000.0,
#  550000.0,
#  610750.0,
#  550700.0,
#  665000.0,
#  834000.0,
#  201000.0,
#  2384000.0,
#  1384000.0,
#  1400000.0,
#  305000.0,
#  487000.0,
#  390000.0,
#  548000.0,
#  268750.0,
#  819900.0,
#  520000.0,
#  230000.0,
#  240000.0,
#  232000.0,
#  240500.0,
#  274975.0,
#  740000.0,
#  186375.0,
#  790000.0,
#  880000.0,
#  279000.0,
#  295000.0,
#  640000.0,
#  940000.0,
#  260000.0,
#  559900.0,
#  791500.0,
#  265000.0,
#  245000.0,
#  485000.0,
#  684000.0,
#  425000.0,
#  309600.0,
#  552250.0,
#  165000.0,
#  239900.0,
#  320000.0,
#  206600.0,
#  387000.0,
#  299000.0,
#  855000.0,
#  315000.0,
#  437500.0,
#  252000.0,
#  375000.0,
#  300000.0,
#  420000.0,
#  900000.0,
#  679900.0,
#  463000.0,
#  380000.0,
#  329500.0,
#  604950.0,
#  795000.0,
#  465000.0,
#  673000.0,
#  810000.0,
#  785000.0,
#  338000.0,
#  280000.0,
#  315000.0,
#  530000.0,
#  380000.0,
#  297000.0,
#  730000.0,
#  450000.0,
#  275000.0,
#  595000.0,
#  435000.0,
#  270000.0,
#  950000.0,
#  389000.0,
#  560000.0,
#  1350000.0,
#  799000.0,
#  365500.0,
#  252350.0,
#  403950.0,
#  385000.0,
#  345000.0,
#  490000.0,
#  330000.0,
#  927000.0,
#  1118000.0,
#  330000.0,
#  530000.0,
#  365000.0,
#  378750.0,
#  269900.0,
#  557000.0,
#  360000.0,
#  352000.0,
#  437000.0,
#  322500.0,
#  650000.0,
#  450000.0,
#  278500.0,
#  364950.0,
#  840000.0,
#  268000.0,
#  517534.0,
#  632925.0,
#  577500.0,
#  339000.0,
#  570000.0,
#  563500.0,
#  423000.0,
#  355000.0,
#  1550000.0,
#  482000.0,
#  625000.0,
#  538000.0,
#  380000.0,
#  375000.0,
#  245000.0,
#  310000.0,
#  1300000.0,
#  397000.0,
#  365000.0,
#  328500.0,
#  988000.0,
#  1000000.0,
#  237000.0,
#  525000.0,
#  749000.0,
#  722500.0,
#  843000.0,
#  438000.0,
#  578000.0,
#  227950.0,
#  196000.0,
#  641000.0,
#  350000.0,
#  205000.0,
#  400000.0,
#  1030000.0,
#  505000.0,
#  475000.0,
#  520000.0,
#  1450000.0,
#  333500.0,
#  232000.0,
#  691100.0,
#  811000.0,
#  551000.0,
#  496500.0,
#  705000.0,
#  578000.0,
#  255000.0,
#  1050000.0,
#  348000.0,
#  230000.0,
#  359500.0,
#  330000.0,
#  80000.0,
#  465000.0,
#  325000.0,
#  340500.0,
#  342500.0,
#  290900.0,
#  868700.0,
#  1199000.0,
#  1150000.0,
#  859900.0,
#  520000.0,
#  460000.0,
#  438924.0,
#  315000.0,
#  590000.0,
#  378500.0,
#  328500.0,
#  849950.0,
#  525000.0,
#  1385000.0,
#  295000.0,
#  1067000.0,
#  207950.0,
#  699900.0,
#  1280000.0,
#  452000.0,
#  370000.0,
#  232000.0,
#  669950.0,
#  397500.0,
#  490000.0,
#  725000.0,
#  299000.0,
#  625000.0,
#  437500.0,
#  650000.0,
#  475000.0,
#  342000.0,
#  1197350.0,
#  280000.0,
#  240000.0,
#  529000.0,
#  442000.0,
#  615000.0,
#  1485000.0,
#  585000.0,
#  480000.0,
#  1095000.0,
#  290000.0,
#  615000.0,
#  300000.0,
#  308000.0,
#  750000.0,
#  2250000.0,
#  890000.0,
#  288000.0,
#  190000.0,
#  515000.0,
#  235000.0,
#  275000.0,
#  727500.0,
#  650000.0,
#  1600000.0,
#  365000.0,
#  662000.0,
#  270500.0,
#  200000.0,
#  970000.0,
#  160000.0,
#  204000.0,
#  358000.0,
#  452000.0,
#  595000.0,
#  249000.0,
#  346900.0,
#  2125000.0,
#  280000.0,
#  318888.0,
#  530000.0,
#  375000.0,
#  910000.0,
#  782000.0,
#  259950.0,
#  315000.0,
#  215000.0,
#  705000.0,
#  1450000.0,
#  451000.0,
#  261000.0,
#  396000.0,
#  725000.0,
#  1950000.0,
#  238000.0,
#  750000.0,
#  331500.0,
#  460000.0,
#  404950.0,
#  880000.0,
#  863000.0,
#  638700.0,
#  435000.0,
#  260000.0,
#  671500.0,
#  610000.0,
#  405000.0,
#  338900.0,
#  720000.0,
#  442000.0,
#  650000.0,
#  263500.0,
#  300000.0,
#  266000.0,
#  930000.0,
#  530000.0,
#  180000.0,
#  619000.0,
#  264000.0,
#  730000.0,
#  439000.0,
#  268500.0,
#  330000.0,
#  640000.0,
#  900000.0,
#  370000.0,
#  685000.0,
#  505000.0,
#  265000.0,
#  290000.0,
#  296000.0,
#  360000.0,
#  240500.0,
#  372500.0,
#  595000.0,
#  515000.0,
#  1220000.0,
#  507000.0,
#  399950.0,
#  185000.0,
#  460000.0,
#  435500.0,
#  469000.0,
#  531000.0,
#  443500.0,
#  223000.0,
#  590000.0,
#  340000.0,
#  650000.0,
#  533600.0,
#  695000.0,
#  242000.0,
#  425000.0,
#  525000.0,
#  485000.0,
#  175000.0,
#  210000.0,
#  260000.0,
#  577000.0,
#  200000.0,
#  605000.0,
#  325000.0,
#  289500.0,
#  559950.0,
#  1042500.0,
#  543500.0,
#  480000.0,
#  218000.0,
#  565000.0,
#  426700.0,
#  650000.0,
#  542000.0,
#  415000.0,
#  214000.0,
#  245000.0,
#  314500.0,
#  1120000.0,
#  378000.0,
#  305000.0,
#  595000.0,
#  729500.0,
#  430000.0,
#  240000.0,
#  545000.0,
#  530000.0,
#  157000.0,
#  425000.0,
#  220000.0,
#  521000.0,
#  325000.0,
#  597500.0,
#  337000.0,
#  1000000.0,
#  3070000.0,
#  495000.0,
#  748000.0,
#  888000.0,
#  269900.0,
#  496500.0,
#  475000.0,
#  312000.0,
#  323000.0,
#  331000.0,
#  306000.0,
#  655000.0,
#  290000.0,
#  1250000.0,
#  460000.0,
#  435000.0,
#  664000.0,
#  865000.0,
#  385000.0,
#  497000.0,
#  280000.0,
#  188000.0,
#  478500.0,
#  1145000.0,
#  222000.0,
#  799000.0,
#  609900.0,
#  413000.0,
#  400000.0,
#  802541.0,
#  320000.0,
#  507000.0,
#  387500.0,
#  396000.0,
#  373000.0,
#  1484900.0,
#  359900.0,
#  410000.0,
#  690000.0,
#  245000.0,
#  700000.0,
#  268000.0,
#  225000.0,
#  980000.0,
#  795000.0,
#  195000.0,
#  480000.0,
#  485000.0,
#  130000.0,
#  325000.0,
#  440000.0,
#  550000.0,
#  310000.0,
#  530000.0,
#  390000.0,
#  243000.0,
#  639000.0,
#  215000.0,
#  405000.0,
#  250000.0,
#  405500.0,
#  452000.0,
#  730000.0,
#  267000.0,
#  289950.0,
#  565000.0,
#  1578000.0,
#  636000.0,
#  350000.0,
#  320000.0,
#  210000.0,
#  245000.0,
#  328000.0,
#  985000.0,
#  501000.0,
#  315000.0,
#  403000.0,
#  550000.0,
#  347500.0,
#  365000.0,
#  588000.0,
#  605000.0,
#  1300000.0,
#  233000.0,
#  360000.0,
#  459000.0,
#  740000.0,
#  305000.0,
#  395000.0,
#  560000.0,
#  650000.0,
#  449950.0,
#  517500.0,
#  435000.0,
#  329999.0,
#  950000.0,
#  447000.0,
#  699800.0,
#  850000.0,
#  316500.0,
#  942500.0,
#  1310000.0,
#  856600.0,
#  405600.0,
#  565000.0,
#  400000.0,
#  330000.0,
#  374950.0,
#  405300.0,
#  560000.0,
#  824000.0,
#  260000.0,
#  760000.0,
#  405000.0,
#  429900.0,
#  341500.0,
#  465250.0,
#  450000.0,
#  390000.0,
#  420000.0,
#  269950.0,
#  493000.0,
#  370000.0,
#  2250000.0,
#  305000.0,
#  400000.0,
#  320000.0,
#  715000.0,
#  650000.0,
#  218000.0,
#  500000.0,
#  460000.0,
#  232500.0,
#  408200.0,
#  522000.0,
#  675000.0,
#  1355000.0,
#  249950.0,
#  210000.0,
#  429950.0,
#  737500.0,
#  710000.0,
#  470000.0,
#  1100000.0,
#  650000.0,
#  1216000.0,
#  422120.0,
#  625000.0,
#  385200.0,
#  500000.0,
#  308000.0,
#  565000.0,
#  581000.0,
#  361000.0,
#  345000.0,
#  419000.0,
#  347000.0,
#  625000.0,
#  2400000.0,
#  379000.0,
#  310000.0,
#  250000.0,
#  682000.0,
#  246500.0,
#  325000.0,
#  310950.0,
#  1100000.0,
#  287500.0,
#  431000.0,
#  226000.0,
#  825000.0,
#  175000.0,
#  465750.0,
#  659000.0,
#  595000.0,
#  350000.0,
#  270000.0,
#  662500.0,
#  249900.0,
#  324500.0,
#  430000.0,
#  419950.0,
#  285000.0,
#  332000.0,
#  282000.0,
#  320000.0,
#  428750.0,
#  330000.0,
#  456500.0,
#  352000.0,
#  664000.0,
#  628000.0,
#  512000.0,
#  254000.0,
#  535800.0,
#  287653.0,
#  438000.0,
#  450000.0,
#  327000.0,
#  370500.0,
#  265000.0,
#  450000.0,
#  425000.0,
#  166600.0,
#  245000.0,
#  565000.0,
#  539900.0,
#  910000.0,
#  280000.0,
#  275000.0,
#  467000.0,
#  457500.0,
#  381156.0,
#  289999.0,
#  642450.0,
#  469950.0,
#  795000.0,
#  785000.0,
#  860000.0,
#  1095000.0,
#  147500.0,
#  390000.0,
#  229000.0,
#  185000.0,
#  414900.0,
#  200000.0,
#  225000.0,
#  720000.0,
#  930000.0,
#  1270000.0,
#  700000.0,
#  466000.0,
#  374000.0,
#  480000.0,
#  740000.0,
#  1010000.0,
#  395000.0,
#  340000.0,
#  209000.0,
#  431650.0,
#  980000.0,
#  660000.0,
#  730000.0,
#  291500.0,
#  905000.0,
#  800000.0,
#  839900.0,
#  200000.0,
#  300000.0,
#  530000.0,
#  314950.0,
#  255000.0,
#  550000.0,
#  435000.0,
#  234000.0,
#  615000.0,
#  205000.0,
#  384000.0,
#  324000.0,
#  645000.0,
#  570000.0,
#  324000.0,
#  270000.0,
#  290000.0,
#  250000.0,
#  342000.0,
#  255000.0,
#  800000.0,
#  451000.0,
#  990000.0,
#  288400.0,
#  420000.0,
#  359000.0,
#  390000.0,
#  300000.0,
#  545000.0,
#  288349.0,
#  299900.0,
#  891000.0,
#  1200000.0,
#  378000.0,
#  299995.0,
#  253000.0,
#  350000.0,
#  565000.0,
#  315000.0,
#  570000.0,
#  971000.0,
#  915000.0,
#  419000.0,
#  260000.0,
#  1321500.0,
#  369950.0,
#  1029900.0,
#  435000.0,
#  601000.0,
#  460500.0,
#  720000.0,
#  851000.0,
#  550000.0,
#  700000.0,
#  323000.0,
#  345500.0,
#  378000.0,
#  650000.0,
#  385000.0,
#  425000.0,
#  210000.0,
#  630000.0,
#  335000.0,
#  196500.0,
#  582800.0,
#  440000.0,
#  752500.0,
#  532500.0,
#  265000.0,
#  397500.0,
#  524250.0,
#  765000.0,
#  648000.0,
#  469500.0,
#  237500.0,
#  216000.0,
#  427200.0,
#  280000.0,
#  718000.0,
#  420000.0,
#  379000.0,
#  326100.0,
#  535000.0,
#  283000.0,
#  260000.0,
#  399000.0,
#  484950.0,
#  640000.0,
#  585000.0,
#  645000.0,
#  253000.0,
#  178500.0,
#  291000.0,
#  199950.0,
#  553500.0,
#  189950.0,
#  289000.0,
#  ...]

# %%
def plot_features_target(top_5_features,target,df):
    x = []
    for feature in top_5_features:
        x.append(list(df[feature]))
    for i in range(len(x)):
        plt.figure()
        plt.scatter(x[i],target)
        plt.xlabel(top_5_features[i])
        plt.ylabel('Price')

# %%
plot_features_target(top_5_features,target,df)

# %%
x = df[top_5_features]

# %%
x
# Out:
#        sqft_living  grade  sqft_above  sqft_living15  bathrooms
# 0             1180      7        1180           1340       1.00
# 1             2570      7        2170           1690       2.25
# 2              770      6         770           2720       1.00
# 3             1960      7        1050           1360       3.00
# 4             1680      8        1680           1800       2.00
# 5             5420     11        3890           4760       4.50
# 6             1715      7        1715           2238       2.25
# 7             1060      7        1060           1650       1.50
# 8             1780      7        1050           1780       1.00
# 9             1890      7        1890           2390       2.50
# 10            3560      8        1860           2210       2.50
# 11            1160      7         860           1330       1.00
# 12            1430      7        1430           1780       1.00
# 13            1370      7        1370           1370       1.75
# 14            1810      7        1810           1360       2.00
# 15            2950      9        1980           2140       3.00
# 16            1890      7        1890           1890       2.00
# 17            1600      7        1600           1610       1.00
# 18            1200      7        1200           1060       1.00
# 19            1250      7        1250           1280       1.00
# 20            1620      7         860           1400       1.75
# 21            3050      9        2330           4110       2.75
# 22            2270      8        2270           2240       2.50
# 23            1070      7        1070           1220       1.50
# 24            2450      8        2450           2200       2.25
# 25            1710      6        1710           1030       2.00
# 26            2450      8        1750           1760       1.75
# 27            1400      8        1400           1860       1.00
# 28            1520      7         790           1520       1.75
# 29            2570      8        2570           2630       2.50
# ...            ...    ...         ...            ...        ...
# 21583          710      7         710           1370       1.00
# 21584         1260      7         940           1310       2.50
# 21585         1870      7        1870           2170       2.50
# 21586         1430      8        1430           1430       2.50
# 21587         1520      8        1520           1520       2.50
# 21588         1210      8        1020           1210       1.50
# 21589         2540      8        2540           2540       2.50
# 21590         4910     11        3110           4560       3.50
# 21591         2770      8        2770           1810       2.75
# 21592         1190      8        1190           1180       2.25
# 21593         4170     10        4170           3030       3.75
# 21594         2500      8        2500           2530       2.75
# 21595         1530      8        1480           1530       2.25
# 21596         3600      9        3600           3550       2.75
# 21597         3410     10        3410           2290       3.25
# 21598         3118      9        3118           2673       2.50
# 21599         3990      9        3990           3370       3.00
# 21600         4470     11        4470           2780       3.75
# 21601         1425      8        1425           1285       2.50
# 21602         1500      6        1500           1320       1.75
# 21603         2270      8        2270           2270       2.50
# 21604         1490      8        1490           1400       2.00
# 21605         2520      9        2520           2520       2.50
# 21606         3510      9        2600           2050       3.50
# 21607         1310      8        1180           1330       2.50
# 21608         1530      8        1530           1530       2.50
# 21609         2310      8        2310           1830       2.50
# 21610         1020      7        1020           1020       0.75
# 21611         1600      8        1600           1410       2.50
# 21612         1020      7        1020           1020       0.75
#
# [21613 rows x 5 columns]

# %%
target = df.iloc[:,2].name
y = df[[target]]

# %%
y
# Out:
#            price
# 0       221900.0
# 1       538000.0
# 2       180000.0
# 3       604000.0
# 4       510000.0
# 5      1225000.0
# 6       257500.0
# 7       291850.0
# 8       229500.0
# 9       323000.0
# 10      662500.0
# 11      468000.0
# 12      310000.0
# 13      400000.0
# 14      530000.0
# 15      650000.0
# 16      395000.0
# 17      485000.0
# 18      189000.0
# 19      230000.0
# 20      385000.0
# 21     2000000.0
# 22      285000.0
# 23      252700.0
# 24      329000.0
# 25      233000.0
# 26      937000.0
# 27      667000.0
# 28      438000.0
# 29      719000.0
# ...          ...
# 21583   399950.0
# 21584   380000.0
# 21585   270000.0
# 21586   505000.0
# 21587   385000.0
# 21588   414500.0
# 21589   347500.0
# 21590  1222500.0
# 21591   572000.0
# 21592   475000.0
# 21593  1088000.0
# 21594   350000.0
# 21595   520000.0
# 21596   679950.0
# 21597  1575000.0
# 21598   541800.0
# 21599   810000.0
# 21600  1537000.0
# 21601   467000.0
# 21602   224000.0
# 21603   507250.0
# 21604   429000.0
# 21605   610685.0
# 21606  1007500.0
# 21607   475000.0
# 21608   360000.0
# 21609   400000.0
# 21610   402101.0
# 21611   400000.0
# 21612   325000.0
#
# [21613 rows x 1 columns]

# %%
from sklearn.cross_validation import train_test_split
# Out:
# C:\Users\Pawan\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (15129, 5)
# (6484, 5)
# (15129, 1)
# (6484, 1)

# %%
from sklearn.linear_model import LinearRegression
lg = LinearRegression()

# %%
lg.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred = lg.predict(x_test)

# %%
y_pred
# Out:
# array([[ 602046.42522605],
#        [ 567886.49256366],
#        [ 156073.4693375 ],
#        ...,
#        [ 302937.4942582 ],
#        [1032540.95139979],
#        [1024657.82908011]])

# %%
lg.score(x_test,y_test)
# Out:
# 0.5309903819211692

# %%
x  = df.iloc[:,3:]
y = df.iloc[:,2]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3)

# %%
lg_all = LinearRegression()

# %%
lg_all.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lg_all.score(x_test,y_test)
# Out:
# 0.705010002417501

# %%
from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler(feature_range = (0,1))

x_min_max_scaler = min_max_scaler.fit(x)

# %%
x = min_max_scaler.transform(x)

# %%
x
# Out:
# array([[0.09090909, 0.125     , 0.06716981, ..., 0.21760797, 0.16193426,
#         0.00574235],
#        [0.09090909, 0.28125   , 0.17207547, ..., 0.16611296, 0.22216486,
#         0.00802712],
#        [0.06060606, 0.125     , 0.03622642, ..., 0.23754153, 0.3994149 ,
#         0.00851302],
#        ...,
#        [0.06060606, 0.09375   , 0.05509434, ..., 0.18272425, 0.10686629,
#         0.00155764],
#        [0.09090909, 0.3125    , 0.09886792, ..., 0.37375415, 0.17398038,
#         0.00073057],
#        [0.06060606, 0.09375   , 0.05509434, ..., 0.18272425, 0.10686629,
#         0.00081098]])

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3)

# %%
lg_fs = LinearRegression()

# %%
lg_fs.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lg_fs.score(x_test,y_test)
# Out:
# 0.6887136045441988

# %%
test1 = [[5,1,1180,5650,1,0,0,3,17,1180,0,1955,0,98178,47.5112,-122.257,1340,5650]]


test2 = [[3,1,1180,5650,1,0,0,3,7,1180,0,1955,0,98178,47.5112,-122.257,1340,5650]]

# %%
lg_fs.predict(test1)
# Out:
# array([1061106.8726237])

# %%
lg_fs.predict(test2)  #221900
# Out:
# array([204410.7841398])

# %%
lg_fs.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-45a877bb8691> in <module>()
# ----> 1 lg_fs.summary()
#
# AttributeError: 'LinearRegression' object has no attribute 'summary'

# %%
list_coff= lg_fs.coef_

# %%
list_coff
# Out:
# array([-1.17325161e+06,  2.93259904e+05, -1.23380764e+17,  2.71430496e+05,
#         2.83579653e+04,  5.64830885e+05,  2.04620078e+05,  1.02998893e+05,
#         1.21734479e+06,  8.49232124e+16,  4.48826627e+16, -2.99753224e+05,
#         3.09013172e+04, -1.10297484e+05,  3.67100234e+05, -2.51779801e+05,
#         1.66853889e+05, -3.70908001e+05])

# %%
list_intercept = lg_fs.intercept_

# %%
list_intercept
# Out:
# -459560.5706920484
